# %%
import os
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
os.chdir(r'F:\college\herovired\data')
os.getcwd()
# Out:
# 'F:\\college\\herovired\\data'

# %%
os.listdir()
# Out:
# ['02 Office Supplies Orders Case Study Data.csv',
#  '02 Office Supplies Orders Case Study Data.xlsx',
#  'bank_data (1).csv',
#  'Data set-20220301.zip']

# %%
df=pd.read_csv('02 Office Supplies Orders Case Study Data.csv')
df
# Out:
#                        Order ID  Order Date   Ship Date       Ship Mode  \
# 0      CA-2014-AB10015140-41954  11-11-2014  13-11-2014     First Class
# 1        IN-2014-JR162107-41675  05-02-2014  07-02-2014    Second Class
# 2        IN-2014-CR127307-41929  17-10-2014  18-10-2014     First Class
# 3       ES-2014-KM1637548-41667  28-01-2014  30-01-2014     First Class
# 4       SG-2014-RH9495111-41948  05-11-2014  06-11-2014        Same Day
# ...                         ...         ...         ...             ...
# 51285   IN-2015-KE1642066-42174  19-06-2015  19-06-2015        Same Day
# 51286  US-2014-ZD21925140-41765  06-05-2014  10-05-2014  Standard Class
# 51287  CA-2012-ZD21925140-41147  26-08-2012  31-08-2012    Second Class
# 51288   MX-2013-RB1979518-41322  17-02-2013  21-02-2013  Standard Class
# 51289   MX-2013-MC1810093-41416  22-05-2013  26-05-2013    Second Class
#
#         Customer ID       Customer Name      Segment  Postal Code  \
# ...

# %%
ss=pd.read_excel('02 Office Supplies Orders Case Study Data.xlsx',sheet_name="Data")
ss
# Out:
#                        Order ID Order Date  Ship Date       Ship Mode  \
# 0      CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1        IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2        IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...                         ...        ...        ...             ...
# 51285   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
#         Customer ID       Customer Name      Segment  Postal Code  \
# ...

# %%
ss.describe()
# Out:
#         Postal Code         Sales      Quantity      Discount        Profit  \
# count   9994.000000  51290.000000  51290.000000  51290.000000  51290.000000
# mean   55190.379428    246.490581      3.476545      0.142908     28.610982
# std    32063.693350    487.565361      2.278766      0.212280    174.340972
# min     1040.000000      0.444000      1.000000      0.000000  -6599.978000
# 25%    23223.000000     30.758625      2.000000      0.000000      0.000000
# 50%    56430.500000     85.053000      3.000000      0.000000      9.240000
# 75%    90008.000000    251.053200      5.000000      0.200000     36.810000
# max    99301.000000  22638.480000     14.000000      0.850000   8399.976000
#
#        Shipping Cost
# count   51290.000000
# mean       26.478567
# std        57.251373
# min         1.002000
# 25%         2.610000
# 50%         7.790000
# 75%        24.450000
# max       933.570000

# %%
ss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        51290 non-null  object
#  1   Order Date      51290 non-null  datetime64[ns]
#  2   Ship Date       51290 non-null  datetime64[ns]
#  3   Ship Mode       51290 non-null  object
#  4   Customer ID     51290 non-null  object
#  5   Customer Name   51290 non-null  object
#  6   Segment         51290 non-null  object
#  7   Postal Code     9994 non-null   float64
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Region          51290 non-null  object
#  12  Market          51290 non-null  object
#  13  Product ID      51290 non-null  object
#  14  Category        51290 non-null  object
#  15  Sub-Category    51290 non-null  object
# ...

# %%
ss['Postal Code'].isnull().value()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-078a84f46ead> in <module>
# ----> 1 ss['Postal Code'].isnull().value()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'value'

# %%
ss.isnull().sum()
# Out:
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# Postal Code       41296
# City                  0
# State                 0
# Country               0
# Region                0
# Market                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
ss['Postal Code'].isnull().mean()
# Out:
# 0.8051472021836615

# %%
ss['Postal Code'].mean()
# Out:
# 55190.3794276566

# %%
ss['postal_code']=ss['Postal Code'].fillna(ss['Postal Code'].mean())
ss
# Out:
#                        Order ID Order Date  Ship Date       Ship Mode  \
# 0      CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1        IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2        IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...                         ...        ...        ...             ...
# 51285   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
#         Customer ID       Customer Name      Segment  Postal Code  \
# ...

# %%
ss.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Length: 51290, dtype: bool

# %%
ss.duplicated().sum()
# Out:
# 0

# %%
df.isnull()
# Out:
#        Order ID  Order Date  Ship Date  Ship Mode  Customer ID  Customer Name  \
# 0         False       False      False      False        False          False
# 1         False       False      False      False        False          False
# 2         False       False      False      False        False          False
# 3         False       False      False      False        False          False
# 4         False       False      False      False        False          False
# ...         ...         ...        ...        ...          ...            ...
# 51285     False       False      False      False        False          False
# 51286     False       False      False      False        False          False
# 51287     False       False      False      False        False          False
# 51288     False       False      False      False        False          False
# 51289     False       False      False      False        False          False
#
# ...
